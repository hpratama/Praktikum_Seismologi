# %% [markdown]
# # No. 1 Gempa Indonesia pada Kedalaman Dangkal dan Dalam

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame,Series
import matplotlib.pyplot as plt

# %%
slw = pd.read_csv('shallow.csv', sep=',')
slw
# Out:
#                         time  latitude  longitude  depth  mag magType  nst  \
# 0   2018-01-23T06:34:54.240Z   -7.1958   105.9181  43.91  6.0     mww  NaN
# 1   2017-10-31T11:50:48.370Z   -3.7449   127.7517   6.00  6.1     mww  NaN
# 2   2017-08-31T17:06:55.750Z   -1.1590    99.6881  43.14  6.3     mww  NaN
# 3   2017-08-13T03:08:10.560Z   -3.7682   101.6228  31.00  6.4     mww  NaN
# 4   2017-05-29T14:35:21.510Z   -1.2923   120.4313  12.00  6.6     mww  NaN
# 5   2017-04-28T20:23:17.260Z    5.5043   125.0658  26.00  6.9     mww  NaN
# 6   2016-12-06T22:03:33.390Z    5.2834    96.1678  13.00  6.5     mww  NaN
# 7   2016-09-17T01:20:17.940Z   -2.0829   140.5718   9.00  6.0     mww  NaN
# 8   2016-06-09T04:13:08.130Z  -11.2487   116.2669  19.00  6.1     mww  NaN
# 9   2016-06-07T19:15:15.330Z    1.2789   126.3712  31.00  6.3     mww  NaN
# 10  2016-06-01T22:56:00.800Z   -2.0967   100.6654  50.00  6.6     mww  NaN
# ...

# %% [markdown]
# Tabel diatas merupakan katalog gempa dengan magnitudo yang lebih dari 6 mww, yang terjadi pada kedalaman yang dangkal yaitu 0-70 km. Adapun dapat kita lihat gempa dengan magnitudo besar dan kedalaman yang dangkal banyak terjadi di daerah timur Indonesia. Hal ini terjadi karena pada daerah timur Indonesia terdapat pertemuan lempeng eurasia dan lempeng pasifik, yang membuat aktifitas tektonik sering terjadi di wilayah ini.

# %%
deep = pd.read_csv('deep.csv', sep=',')
deep
# Out:
#                        time  latitude  longitude  depth  mag magType  nst  \
# 0  2017-12-15T16:47:58.230Z   -7.4921   108.1743     90  6.5     mww  NaN
# 1  2016-12-29T22:30:19.300Z   -9.0279   118.6639     79  6.3     mww  NaN
# 2  2016-12-21T00:17:14.990Z   -7.5082   127.9206    152  6.7     mww  NaN
#
#    gap   dmin   rms    ...                      updated  \
# 0   28  2.365  1.07    ...     2018-02-02T14:53:34.714Z
# 1   26  3.553  1.42    ...     2017-03-23T22:52:09.040Z
# 2   17  3.380  1.20    ...     2017-03-16T02:31:31.040Z
#
#                              place        type horizontalError depthError  \
# 0  1km E of Kampungbaru, Indonesia  earthquake             8.0        1.8
# 1  29km S of Tolotangga, Indonesia  earthquake             6.2        1.8
# 2    283km ENE of Dili, East Timor  earthquake             5.3        1.8
#
#    magError  magNst    status  locationSource magSource
# 0     0.058    29.0  reviewed              us        us
# ...

# %% [markdown]
# Tabel diatas merupakan katalog gempa yang terjadi di Indonesia dengan kedalaman yang dalam (70-300km) dan dengan magnitudo lebih dari 6 Mw. Dibandingkan dengan gempa pada kedalaman dangkal, dengan rentang magnitudo yang sama gempa pada kedalaman yang dalam jarang terjadi di Indonesia. Tercatat dari tahun 2016 sampai awal tahun 2018 hanya ada 2 event di Indonesia dan 1 di Timor-timor.

# %%
al = pd.read_csv('all.csv', sep=',')
al
# Out:
#                         time  latitude  longitude   depth  mag magType  nst  \
# 0   2018-01-23T06:34:54.240Z   -7.1958   105.9181   43.91  6.0     mww  NaN
# 1   2017-12-15T16:47:58.230Z   -7.4921   108.1743   90.00  6.5     mww  NaN
# 2   2017-10-31T11:50:48.370Z   -3.7449   127.7517    6.00  6.1     mww  NaN
# 3   2017-08-31T17:06:55.750Z   -1.1590    99.6881   43.14  6.3     mww  NaN
# 4   2017-08-13T03:08:10.560Z   -3.7682   101.6228   31.00  6.4     mww  NaN
# 5   2017-05-29T14:35:21.510Z   -1.2923   120.4313   12.00  6.6     mww  NaN
# 6   2017-04-28T20:23:17.260Z    5.5043   125.0658   26.00  6.9     mww  NaN
# 7   2016-12-29T22:30:19.300Z   -9.0279   118.6639   79.00  6.3     mww  NaN
# 8   2016-12-21T00:17:14.990Z   -7.5082   127.9206  152.00  6.7     mww  NaN
# 9   2016-12-06T22:03:33.390Z    5.2834    96.1678   13.00  6.5     mww  NaN
# 10  2016-09-17T01:20:17.940Z   -2.0829   140.5718    9.00  6.0     mww  NaN
# ...

# %% [markdown]
# Tabel berikut merupakan katalog seluruh gempa dengan magnitudo lebih dari 6 mw yang terjadi di Indonesia pada rentang waktu 2 tahun. Tercatat gempa dengan magnitudo lebih dari 6 mw banyak terjadi pada kedalaman dangkal (0-70km)

# %% [markdown]
# ## No. 2 Arrival Time Catalogue
